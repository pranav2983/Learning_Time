# %%
import os

cwd = os.getcwd()
print(f"my current working dir is {cwd}")
# Out:
# my current working dir is /Users/pranavsingh/Python/6-File_Handling

# %%
## create a new directory

new_dir = "Package"
os.mkdir(new_dir)
print(f" directory '{new_dir}' created")
# Out:
#  directory 'Package' created

# %%
## listing  files and directories

items = os.listdir('.')
print(items)
# Out:
# ['destination.txt', '2-file_paths.ipynb', 'source.txt', '1-fileoperation.ipynb', 'example.bin', 'example.txt', 'Package']

# %%
## Joining Paths

dir_name = "folder"
file_name = "file.txt"
relative_path = os.path.join(dir_name,file_name)

print(relative_path)

full_path = os.path.join(os.getcwd(), dir_name, file_name)

print(full_path)
# Out:
# folder/file.txt
# /Users/pranavsingh/Python/6-File_Handling/folder/file.txt

# %%
## checking the file is present or not

path = "sources.txt"
if os.path.exists(path):
    print(f"path '{path}' exists ")
else:
    print(f"path '{path}' does not exists ")
# Out:
# path 'sources.txt' does not exists

# %%
## checking if a path is a file or a directory

import os

path = "source.txt"

if os.path.isfile(path):
    print(f" the path '{path}' is a file.")
elif os.path.isdir(path):
    print(f" the path '{path}' is a directory.")
else:
    print(f"The path '{path}' is neither a file nor a directory.")
# Out:
#  the path 'source.txt' is a file.

# %%
## getting the absolute path 

relative_path = "source.txt"
absolute_path = os.path.join(os.getcwd(), relative_path)
absolute_path1 = os.path.abspath(relative_path)
print(absolute_path)
print(absolute_path1)
# Out:
# /Users/pranavsingh/Python/6-File_Handling/source.txt
# /Users/pranavsingh/Python/6-File_Handling/source.txt
